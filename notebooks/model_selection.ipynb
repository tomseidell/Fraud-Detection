# %% [markdown]
# # Model Selection
# This Notebook tests multiple different Machine Learning Algos against our given Problem.
# This should give us a first overview and indication towards which models will perform best.
# Additionally we will perform Benchmarks, such as RandomGuessing and ZeroGuessing in order to have a real world comparison
# The different modells we will test are:
# - Random Forest
# - Decision Tree
# - XGBoost
# - Neural Networks
#
# ## Evaluation Metrics
# To evaluate and compare our modell we will use typical classification metrics:
# - Recall
# - Precision
# - F1
# - ROC-AUC (chooses indpendent treshold for classification. Simply meassures if true has higher % outcome than false)

# %% [markdown]
# ### Load merged Dataset
# this Dataset consists of 3 subests:
# - X_train, y_train (70%)
# - X_val, y_val (15%)
# - X_test, y_test (15%)

# %%
import sys
sys.path.append('..')  
from src.data.data import Data

data = Data()
X_train, X_val, X_test, y_train, y_val, y_test= data.prepare_data()
# Out:
# /Users/tomseidel/Desktop/Learning/ML/fraud-detection/notebooks/../src/data/data.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.df["DT_day"] = self.df["TransactionDT"] // 86400
# /Users/tomseidel/Desktop/Learning/ML/fraud-detection/notebooks/../src/data/data.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.df["DT_hour"] = (self.df["TransactionDT"] // 3600) % 24
# /Users/tomseidel/Desktop/Learning/ML/fraud-detection/notebooks/../src/data/data.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.df["DT_weekday"] = self.df["DT_day"] % 7
